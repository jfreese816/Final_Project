# %%
import pandas as pd
import re

# %%
df=pd.read_csv("resources/post_data_user3_MBJ.csv",encoding='ISO 8859-1')

# %%
df=df.iloc[0:112,]
df['text']=df['text'].astype(str)
df
# Out:
# /Users/amy/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Unnamed: 0      author    shortcode   timestamp   likes  comments  \
# 0             0    shmee150  CSzoxcyrzj2  1629485286   19080        49
# 1             1    shmee150  CSr2jQPjy59  1629224075   22143       100
# 2             2    shmee150  CSpWzdxJIIV  1629140321   21606       130
# 3             3    shmee150  CSkdxyJAk2n  1628976206   30069       113
# 4             4    shmee150  CSfHSEzi3BD  1628796639   34073       140
# ..          ...         ...          ...         ...     ...       ...
# 107         107  Jaclynhill  CQUGcKMj7xb  1624132132  291459      3474
# 108         108     garyvee  CS2ivLCMy5V  1629582785   24615       850
# 109         109     garyvee  CS17uAQALn9  1629562447   29599       573
# 110         110     garyvee  CS0KgsvgmDM  1629503028   42001       964
# 111         111     garyvee  CSy-aVlsUKn  1629463077  142180      1751
#
#                                                caption  \
# 0    Photo shared by Tim - Shmee on August 20, 2021...
# 1    Photo shared by Tim - Shmee on August 17, 2021...
# 2    Photo shared by Tim - Shmee on August 16, 2021...
# 3    Photo shared by Tim - Shmee on August 14, 2021...
# 4    Photo shared by Tim - Shmee on August 12, 2021...
# ..                                                 ...
# 107  Photo by J A C L Y N ð on June 19, 2021. Ma...
# 108  Photo by Gary Vay-Ner-Chuk on August 21, 2021....
# 109                                                NaN
# 110                                                NaN
# 111  Photo by Gary Vay-Ner-Chuk on August 20, 2021....
#
#                                                   text
# 0    Back at the wheel of an SF90! With @bannedauto...
# 1    It's a P1 kinda day! Out for a drive in @super...
# 2    The beautiful 300SL Roadster is without a shad...
# 3    The breathtaking @bugatti Bolide at @thequaile...
# 4    The new @astonmartinlagonda Valkyrie Spider ha...
# ..                                                 ...
# 107  Its been 2 weeks since I started an anti-infl...
# 108  Dont get it twisted
#  this is gonna be the b...
# 109  GRATITUDE FOR WHAT YOU HAVE Versus COMPLAINING...
# 110  ?? Youve asked for it, you got it
#  another e...
# 111  Enough of this fail shit. Life isnt so perm...
#
# [112 rows x 8 columns]

# %%
hash_tag=[]
a=[]
post=[]
for x in df['text']:
    a=x.split()
    post=[]
    for y in a:
        m = re.findall(r'(?<=#)\w+', y)
        post.append(m)
    hash_tag.append(post)

# %%
df['hash_tag']=hash_tag
# Out:
# /Users/amy/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hash_tag2=[]
for x in df['hash_tag']:
    res = list(filter(None, x))
    hash_tag2.append(res)

# %%
df['Hash_tag2']=hash_tag2
df.drop(columns="hash_tag",inplace=True)
# Out:
# /Users/amy/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/amy/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#      Unnamed: 0      author    shortcode   timestamp   likes  comments  \
# 0             0    shmee150  CSzoxcyrzj2  1629485286   19080        49
# 1             1    shmee150  CSr2jQPjy59  1629224075   22143       100
# 2             2    shmee150  CSpWzdxJIIV  1629140321   21606       130
# 3             3    shmee150  CSkdxyJAk2n  1628976206   30069       113
# 4             4    shmee150  CSfHSEzi3BD  1628796639   34073       140
# ..          ...         ...          ...         ...     ...       ...
# 107         107  Jaclynhill  CQUGcKMj7xb  1624132132  291459      3474
# 108         108     garyvee  CS2ivLCMy5V  1629582785   24615       850
# 109         109     garyvee  CS17uAQALn9  1629562447   29599       573
# 110         110     garyvee  CS0KgsvgmDM  1629503028   42001       964
# 111         111     garyvee  CSy-aVlsUKn  1629463077  142180      1751
#
#                                                caption  \
# 0    Photo shared by Tim - Shmee on August 20, 2021...
# 1    Photo shared by Tim - Shmee on August 17, 2021...
# 2    Photo shared by Tim - Shmee on August 16, 2021...
# 3    Photo shared by Tim - Shmee on August 14, 2021...
# 4    Photo shared by Tim - Shmee on August 12, 2021...
# ..                                                 ...
# 107  Photo by J A C L Y N ð on June 19, 2021. Ma...
# 108  Photo by Gary Vay-Ner-Chuk on August 21, 2021....
# 109                                                NaN
# 110                                                NaN
# 111  Photo by Gary Vay-Ner-Chuk on August 20, 2021....
#
#                                                   text  \
# 0    Back at the wheel of an SF90! With @bannedauto...
# 1    It's a P1 kinda day! Out for a drive in @super...
# 2    The beautiful 300SL Roadster is without a shad...
# 3    The breathtaking @bugatti Bolide at @thequaile...
# 4    The new @astonmartinlagonda Valkyrie Spider ha...
# ..                                                 ...
# 107  Its been 2 weeks since I started an anti-infl...
# 108  Dont get it twisted
#  this is gonna be the b...
# 109  GRATITUDE FOR WHAT YOU HAVE Versus COMPLAINING...
# 110  ?? Youve asked for it, you got it
#  another e...
# 111  Enough of this fail shit. Life isnt so perm...
#
#                                              Hash_tag2
# 0    [[Ferrari], [SF90], [futureshmeemobile], [Asse...
# 1    [[McLaren], [P1], [McLarenP1], [testdrive], [C...
# 2    [[Mercedes], [300SL], [PebbleBeach], [CarWeek]...
# 3    [[Bugatti], [Bolide], [Quail], [CarWeek], [Shm...
# 4    [[AstonMartin], [Valkyrie], [ValkyrieSpider], ...
# ..                                                 ...
# 107                                                 []
# 108                                                 []
# 109                                                 []
# 110                            [[OverRatedUnderRated]]
# 111                                                 []
#
# [112 rows x 9 columns]

# %%
¢
