# %% [markdown]
# # Script to Scrape Top Instagram Influencers

# %% [markdown]
# ## Get data

# %%
from bs4 import BeautifulSoup
import requests
import re

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

# %% [markdown]
# ## Preview html tags and text

# %%
url = "https://www.uschamber.com/co/grow/marketing/top-social-media-influencers"
req = requests.get(url, "headers")
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="2020-01-02T08:57:00-05:00" property="article:published_time">
#    <meta content="Nicole Fallon" name="author">
#     <link href="https://www.uschamber.com/co/co/grow/marketing/top-social-media-influencers" rel="canonical"/>
#     <meta content="index, follow" name="robots"/>
#     <title>
#      Top Social Media Influencers by Industry
#     </title>
#     <meta content="These are the top social media influencers across eight major industries, from automotive to fitness to travel. " name="description">
#      <meta content="2239435572971685" property="fb:app_id"/>
#      <meta content="https://www.uschamber.com/co" property="og:site_name">
#       <meta content="https://www.uschamber.com/co/co/grow/marketing/top-social-media-influencers" property="og:url"/>
# ...

# %% [markdown]
# ## Find URLs matching text pattern

# %%
# declare empty list to hold urls
urls = []

# find all <a> tags with href property to find the defined pattern of text to be matched
for link in soup.find_all('a', attrs={'href': re.compile("^https://www.instagram")}):
    print(link.get('href'))
# Out:
# https://www.instagram.com/shmee150/
# https://www.instagram.com/diwd_official/
# https://www.instagram.com/thatdudeinblue/
# https://www.instagram.com/thesmokingtire/
# https://www.instagram.com/hudabeauty
# https://www.instagram.com/jamescharles/
# https://www.instagram.com/rclbeauty101/
# https://www.instagram.com/glamlifeguru/
# https://www.instagram.com/Jaclynhill/
# https://www.instagram.com/garyvee/
# https://www.instagram.com/grantcardone/
# https://www.instagram.com/thesharkdaymond/
# https://www.instagram.com/chiaraferragni/
# https://www.instagram.com/oliviapalermo/
# https://www.instagram.com/marianodivaio/
# https://www.instagram.com/teachingmensfashion/?hl=en
# https://www.instagram.com/evelina/
# https://www.instagram.com/jamieoliver/
# https://www.instagram.com/rosannapansino/?hl=en
# https://www.instagram.com/bingingwithbabish/
# https://www.instagram.com/junskitchen/?hl=en
# https://www.instagram.com/Ninja/
# https://www.instagram.com/markiplier/
# ...

# %%
# opening a file in write mode
f = open("", "w")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-50e24f83fc9c> in <module>()
#       1 # opening a file in write mode
# ----> 2 f = open("../resources/top_ig.txt", "w")
#
# FileNotFoundError: [Errno 2] No such file or directory: '../resources/top_ig.txt'

# %%
# traverse paragraphs from soup
for link in soup.find_all('a', attrs={'href': re.compile("^https://www.instagram")}):
    data = link.get('href')
    f.write(data)
    f.write("\n")
    f.close()
