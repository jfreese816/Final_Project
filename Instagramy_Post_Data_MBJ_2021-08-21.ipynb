# %%
from instagramy import InstagramUser
from instagramy import InstagramPost
import pandas as pd
import time

# %%
# Grab session id: 
# log into Instagram in browser, 
    # inspect page --> 
    # click on application tab --> 
    # expand cookies (left hand side under 'Storage') --> 
    # click on cookie for https://instagram.com --> 
    # copy session id from the table
    
session_id = "145470550%3Apk3dmP5fGaSHHO%3A6"

# %%
# Separately, we created a list of Instagram users from whom we want to pull data
# Import list of users

# Read in separate list of pre-selected usernames into pandas dataframe
user_df = pd.read_csv('resources/top_ig_urls_MJ.csv', header=None)

# Show usernames
user_df
# Out:
#                       0
# 0              shmee150
# 1         diwd_official
# 2        thatdudeinblue
# 3        thesmokingtire
# 4            hudabeauty
# 5          jamescharles
# 6          rclbeauty101
# 7          glamlifeguru
# 8            Jaclynhill
# 9               garyvee
# 10         grantcardone
# 11      thesharkdaymond
# 12       chiaraferragni
# 13        oliviapalermo
# 14        marianodivaio
# 15  teachingmensfashion
# 16              evelina
# 17          jamieoliver
# 18       rosannapansino
# 19    bingingwithbabish
# 20          junskitchen
# 21                Ninja
# 22           markiplier
# 23         SSSniperWolf
# 24         unboxtherapy
# 25                MKBHD
# 26        kayla_itsines
# 27       michelle_lewin
# 28          simeonpanda
# 29           blogilates
# 30          whatsupmoms
# 31        amberfillerup
# 32            glowmaven
# 33     realmomnutrition
# 34        techsavvymama
# 35          funforlouis
# 36         chrisburkard
# 37         wil_dasovich
# 38  thebucketlistfamily
# 39                izkiz
# 40         thrivewithco

# %%
# Set up lists for holding scraped data

post_author = []
post_shortcode = []
post_likes = []
post_comments = []
post_caption = []
post_timestamp = []
post_text = []

# %%
# Set up dual for loops that iterate over each post for each Instagram user
# Append the data items we want to scrape to the empty lists in the previous cell

for x in user_df[0]:
    user = InstagramUser( x, sessionid=session_id)
    post = user.posts
    
    for post in user.posts:
        post_author.append( x)
        post_shortcode.append( post.shortcode)
        post_likes.append( post.likes)
        post_comments.append( post.comments)
        post_caption.append( post.caption)
        post_timestamp.append( post.timestamp)

# %%
# This code isn't running at the moment - may need to wait a couple hours and try running again.

for code in post_shortcode:
    post_initiated = InstagramPost( code)
    post_text.append( post_initiated.text)
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-6dbcdc8b70df> in <module>
#       1 for code in post_shortcode:
# ----> 2     post_initiated = InstagramPost( code)
#       3     post_text.append( post_initiated.text)
#       4     time.sleep(2)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\instagramy\InstagramPost.py in __init__(self, post_id, sessionid, from_cache)
#      66             data = self.get_json()
#      67             cache.make_cache(
# ---> 68                 post_id, data["entry_data"]["PostPage"][0]["graphql"]["shortcode_media"]
#      69             )
#      70             try:
#
# KeyError: 'PostPage'

# %%
# Create dataframe for holding the information we scraped
post_data_df = pd.DataFrame( columns= ['author', 
                                       'shortcode', 
                                       'timestamp', 
                                       'likes',
                                       'comments', 
                                       'caption']) # <-- add , 'text'

# Add 'text' to the list above (put comma after caption and then add), if we can get the code in the prior cell to run

# %%
# Add scraped info into the dataframe
post_data_df.author = post_author
post_data_df.shortcode = post_shortcode
post_data_df.timestamp = post_timestamp
post_data_df.likes = post_likes
post_data_df.comments = post_comments
post_data_df.caption = post_caption

# Un-comment below if we can get the 'text' code to run in the two cells above
# post_data_df.text = post_text

# Show dataframe
post_data_df
# Out:
#            author    shortcode   timestamp  likes  comments  \
# 0        shmee150  CSzoxcyrzj2  1629485286  19080        49
# 1        shmee150  CSr2jQPjy59  1629224075  22143       100
# 2        shmee150  CSpWzdxJIIV  1629140321  21606       130
# 3        shmee150  CSkdxyJAk2n  1628976206  30069       113
# 4        shmee150  CSfHSEzi3BD  1628796639  34073       140
# ..            ...          ...         ...    ...       ...
# 475  thrivewithco  CR9LIYCrPZt  1627657816     15         2
# 476  thrivewithco  CR7P4Xxgy99  1627593199      9         4
# 477  thrivewithco  CR1ZptKNLlR  1627396999      9         3
# 478  thrivewithco  CRonaH9NfBc  1626967999     15         6
# 479  thrivewithco  CRkPfKpsgEE  1626821244     17         4
#
#                                                caption
# 0    Photo shared by Tim - Shmee on August 20, 2021...
# 1    Photo shared by Tim - Shmee on August 17, 2021...
# 2    Photo shared by Tim - Shmee on August 16, 2021...
# 3    Photo shared by Tim - Shmee on August 14, 2021...
# 4    Photo shared by Tim - Shmee on August 12, 2021...
# ..                                                 ...
# 475  Photo shared by CO— by USCC on July 30, 2021 t...
# 476  Photo shared by CO— by USCC on July 29, 2021 t...
# 477  Photo shared by CO— by USCC on July 27, 2021 t...
# 478  Photo by CO— by USCC on July 22, 2021. May be ...
# 479  Photo shared by CO— by USCC on July 20, 2021 t...
#
# [480 rows x 6 columns]

# %%
# Change number and/or change initials in the file name below each time this notebook is run

post_data_df.to_csv('resources/post_data_user3_MBJ.csv')
